# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pickle
import torch
import os

# %%
# def read_outputs(config_file):
#     direc = os.listdir(f"../results/{config_file}")
#     direc.remove("cache")
#     runs = {}
#     for d in direc:
#         with open(f"../results/{config_file}/{d}/00_Loading Predictions/output.pkl", "rb") as f:
#             uncalibrated_results = pickle.load(f)["calibration_validation"]
#             uncalibrated_logits = uncalibrated_results["logits"]
#             labels = uncalibrated_results["labels"]
#         with open(f"../results/{config_file}/{d}/01_Calibration/results.pkl", "rb") as f:
#             results = pickle.load(f)
#             calibrated_logits = results["logits"]
#             prior_class1 = results["prior_class1"]
#         runs[d] = {
#             "uncalibrated_logits": uncalibrated_logits,
#             "calibrated_logits": calibrated_logits,
#             "labels": labels,
#             "prior_class1": prior_class1
#         }
#     return runs

def read_outputs(config_file):
    direc = os.listdir(f"../results/{config_file}")
    direc.remove("cache")
    runs = {}
    for d in direc:
        with open(f"../results/{config_file}/{d}/01_Calibration/results.pkl", "rb") as f:
            results = pickle.load(f)
        lh = results["parameters"].pop("loss_history")
        runs[d] = {
            "validation": {
                "uncalibrated_logits": results["logits"]["uncalibrated_validation"],
                "calibrated_logits": results["logits"]["calibrated_validation"],
                "labels": results["labels"]["validation"],
                "cal_logloss": results["logloss"]["calibrated_validation"],
                "uncal_logloss": results["logloss"]["uncalibrated_validation"]
            },
            "qqp_test": {
                "uncalibrated_logits": results["logits"]["qqp_uncalibrated_test"],
                "calibrated_logits": results["logits"]["qqp_calibrated_test"],
                "labels": results["labels"]["qqp_test"],
                "cal_logloss": results["logloss"]["qqp_calibrated_test"],
                "uncal_logloss": results["logloss"]["qqp_uncalibrated_test"],
            },
            "twitter_test": {
                "uncalibrated_logits": results["logits"]["twitter_uncalibrated_test"],
                "calibrated_logits": results["logits"]["twitter_calibrated_test"],
                "labels": results["labels"]["twitter_test"],
                "cal_logloss": results["logloss"]["twitter_calibrated_test"],
                "uncal_logloss": results["logloss"]["twitter_uncalibrated_test"]
            },
            "training_prior": results["training_prior"],
            "evaluation_prior": results["evaluation_prior"],
            "parameters": results["parameters"],
            "loss_history": lh
        }
    return runs


def plot_logits_histograms(config_file,split="validation"):
    nbins = 100
    runs = read_outputs(config_file)

    for run_name, outputs in runs.items():
        fig, ax = plt.subplots(2,1,figsize=(9,4),sharex=True)
        l = outputs[split]["labels"]
   
        # Uncalibrated logits
        prior = outputs["evaluation_prior"]
        p = outputs[split]["uncalibrated_logits"] - np.log(prior / (1-prior))
        p_class0 = p[l == 0]
        p_class1 = p[l == 1]

        trh_cost01 = - np.log(prior / (1-prior))

        ymax1 = ax[0].hist(p_class0,bins=nbins,alpha=0.5,label="class 0",density=True)[0].max()
        ymax2 = ax[0].hist(p_class1,bins=nbins,alpha=0.5,label="class 1",density=True)[0].max()
        cost = outputs[split]['uncal_logloss']
        norm_cost = -cost / (prior * np.log(prior) + (1-prior) * np.log(1-prior))
        ax[0].plot([],c='w',label=f"Uncalibrated logloss: {norm_cost:.04g}")
        ax[0].grid(True)
        ax[0].legend()
        ax[0].set_title("Uncalibrated LLRs")
        ax[0].vlines([trh_cost01],0,max([ymax1*1.01,ymax2*1.01]),"k","--")
        # ax[0].set_ylim(0,1)
        

        # Calibrated logits
        p = outputs[split]["calibrated_logits"] - np.log(prior / (1-prior))
        p_class0 = p[l == 0]
        p_class1 = p[l == 1]

        ymax1 = ax[1].hist(p_class0,bins=nbins,alpha=0.5,label="class 0",density=True)[0].max()
        ymax2 = ax[1].hist(p_class1,bins=nbins,alpha=0.5,label="class 1",density=True)[0].max()
        cost = outputs[split]['cal_logloss']
        norm_cost = -cost / (prior * np.log(prior) + (1-prior) * np.log(1-prior))
        ax[1].plot([],c='w',label=f"Calibrated logloss: {norm_cost:.04g}")
        ax[1].grid(True)
        ax[1].legend()
        ax[1].set_title("Calibrated LLRs. Temp = {temp:.4f}. Bias = {bias:.4f}".format(**outputs["parameters"]))
        ax[1].vlines([trh_cost01],0,max([ymax1*1.01,ymax2*1.01]),"k","--")
        # ax[1].set_ylim(0,1)

        # ax[2].plot(outputs["loss_history"])
        # ax[2].grid(True)
        # ax[2].set_yscale("log")
        
        fig.suptitle(run_name)
        fig.tight_layout()


plot_logits_histograms("affine",split="qqp_test")
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
def compute_risk(config_file,c12=1,c21=1,split="validation"):
    runs = read_outputs(config_file)
    
    risks = {}
    for run_name, outputs in runs.items():       
        risks[run_name] = {}

        labels = outputs[split]["labels"]
        prior = outputs["evaluation_prior"]
        # trh = np.log(c12 * (1-prior) / (c21 * prior) )
        trh = np.log(c12 / c21)
        preds_b = (prior > (c12 / (c12 + c21))) * np.ones(labels.shape)
        risk_b = c12 * np.sum((labels == 0) & (preds_b == 1)) / np.sum(labels == 0) * (1-prior) + c21 * np.sum((labels == 1) & (preds_b == 0)) / np.sum(labels == 1) * prior

        # p = outputs[split]["uncalibrated_logits"] - np.log(prior / (1-prior))
        # preds = (p > trh).astype(float)
        logits = outputs[split]["uncalibrated_logits"]
        preds = (logits > trh).astype(float)
        risk = c12 * np.sum((labels == 0) & (preds == 1)) / np.sum(labels == 0) * (1-prior) + c21 * np.sum((labels == 1) & (preds == 0)) / np.sum(labels == 1) * prior
        risks[run_name]["uncalibrated"] = risk / risk_b
        
        
        # p = outputs[split]["calibrated_logits"] - np.log(prior / (1-prior))
        # preds = (p > trh).astype(float)
        logits = outputs[split]["calibrated_logits"]
        preds = (logits > trh).astype(float)
        risk = c12 * np.sum((labels == 0) & (preds == 1)) / np.sum(labels == 0) * (1-prior) + c21 * np.mean((labels == 1) & (preds == 0)) / np.sum(labels == 1) * prior
        risks[run_name]["calibrated"] = risk / risk_b
        risks[run_name]["llr_trh"] = trh - np.log(prior / (1-prior))

    return risks

split = "qqp_test"

# for c12 in np.linspace(0.1,1,10):
#     risks = compute_risk("affine",c12=c12,c21=0.8,split=split)
#     for run_name, risk in risks.items():
#         if "0.2_0.2" in run_name:
#             print(f"c12 = {c12:.02}")
#             print(f"UnCalibrated norm risk for {run_name} on {split} split: {risk['uncalibrated']:.04f}")
#             print(f"Calibrated norm risk for {run_name} on {split} split: {risk['calibrated']:.04f}")
#             print()

risks = compute_risk("affine",c12=1,c21=1,split=split)
for run_name, risk in risks.items():
    print(f"UnCalibrated norm risk for {run_name} on {split} split: {risk['uncalibrated']:.04f}")
    print(f"Calibrated norm risk for {run_name} on {split} split: {risk['calibrated']:.04f}")
    print(f"Trh = {risk['llr_trh']:.2f}")
    print()
# Out:
# UnCalibrated norm risk for run13_bert_0.2_0.2 on qqp_test split: 0.5073
# Calibrated norm risk for run13_bert_0.2_0.2 on qqp_test split: 0.2131
# Trh = 1.39
#
# UnCalibrated norm risk for run06_cbow_0.36_0.1 on qqp_test split: 2.0379
# Calibrated norm risk for run06_cbow_0.36_0.1 on qqp_test split: 1.2116
# Trh = 2.20
#
# UnCalibrated norm risk for run02_cbow_0.1_0.36 on qqp_test split: 0.6353
# Calibrated norm risk for run02_cbow_0.1_0.36 on qqp_test split: 0.0187
# Trh = 0.58
#
# UnCalibrated norm risk for run10_bert_0.1_0.2 on qqp_test split: 0.5073
# Calibrated norm risk for run10_bert_0.1_0.2 on qqp_test split: 0.1005
# Trh = 1.39
#
# UnCalibrated norm risk for run03_cbow_0.2_0.1 on qqp_test split: 2.0379
# Calibrated norm risk for run03_cbow_0.2_0.1 on qqp_test split: 0.3552
# Trh = 2.20
#
# UnCalibrated norm risk for run05_cbow_0.2_0.36 on qqp_test split: 0.6353
# Calibrated norm risk for run05_cbow_0.2_0.36 on qqp_test split: 0.0702
# Trh = 0.58
#
# UnCalibrated norm risk for run07_cbow_0.36_0.2 on qqp_test split: 1.0669
# Calibrated norm risk for run07_cbow_0.36_0.2 on qqp_test split: 0.5385
# Trh = 1.39
#
# UnCalibrated norm risk for run17_bert_0.36_0.36 on qqp_test split: 0.2937
# Calibrated norm risk for run17_bert_0.36_0.36 on qqp_test split: 0.1647
# Trh = 0.58
#
# UnCalibrated norm risk for run08_cbow_0.36_0.36 on qqp_test split: 0.6353
# Calibrated norm risk for run08_cbow_0.36_0.36 on qqp_test split: 0.2393
# Trh = 0.58
#
# UnCalibrated norm risk for run15_bert_0.36_0.1 on qqp_test split: 0.9878
# Calibrated norm risk for run15_bert_0.36_0.1 on qqp_test split: 0.8336
# Trh = 2.20
#
# UnCalibrated norm risk for run14_bert_0.2_0.36 on qqp_test split: 0.2937
# Calibrated norm risk for run14_bert_0.2_0.36 on qqp_test split: 0.0947
# Trh = 0.58
#
# UnCalibrated norm risk for run04_cbow_0.2_0.2 on qqp_test split: 1.0669
# Calibrated norm risk for run04_cbow_0.2_0.2 on qqp_test split: 0.1579
# Trh = 1.39
#
# UnCalibrated norm risk for run01_cbow_0.1_0.2 on qqp_test split: 1.0669
# Calibrated norm risk for run01_cbow_0.1_0.2 on qqp_test split: 0.0420
# Trh = 1.39
#
# UnCalibrated norm risk for run00_cbow_0.1_0.1 on qqp_test split: 2.0379
# Calibrated norm risk for run00_cbow_0.1_0.1 on qqp_test split: 0.0944
# Trh = 2.20
#
# UnCalibrated norm risk for run09_bert_0.1_0.1 on qqp_test split: 0.9878
# Calibrated norm risk for run09_bert_0.1_0.1 on qqp_test split: 0.2262
# Trh = 2.20
#
# UnCalibrated norm risk for run16_bert_0.36_0.2 on qqp_test split: 0.5073
# Calibrated norm risk for run16_bert_0.36_0.2 on qqp_test split: 0.3705
# Trh = 1.39
#
# UnCalibrated norm risk for run12_bert_0.2_0.1 on qqp_test split: 0.9878
# Calibrated norm risk for run12_bert_0.2_0.1 on qqp_test split: 0.4795
# Trh = 2.20
#
# UnCalibrated norm risk for run11_bert_0.1_0.36 on qqp_test split: 0.2937
# Calibrated norm risk for run11_bert_0.1_0.36 on qqp_test split: 0.0447
# Trh = 0.58

# %%
runs = read_outputs("affine")
print(runs["run00_cbow_0.1_0.1"]["qqp_test"]["calibrated_logits"].shape)
print(runs["run00_cbow_0.1_0.1"]["qqp_test"]["uncalibrated_logits"].shape)
# Out:
# (40430,)
# (40430,)

# %%
runs = read_outputs("affine")
log_loss = torch.nn.BCEWithLogitsLoss()
for run_name, outputs in runs.items():
    labels = torch.from_numpy(outputs["labels"]).type(torch.float)
    cal_logits = torch.from_numpy(outputs["calibrated_logits"])
    uncal_logits = torch.from_numpy(outputs["uncalibrated_logits"])
    cal_log_loss = log_loss(cal_logits,labels).item()
    uncal_log_loss = log_loss(uncal_logits,labels).item()
    print(f"Model: {run_name.split('_')[1]}. Prior: {run_name.split('_')[3]}.",end=" ")
    print(f"Calibrated log loss: {cal_log_loss:.02f}.",end=" ")
    print(f"Uncalibrated log loss: {uncal_log_loss:.02f}.")
# Out:
# Model: bert. Prior: 0.6. Calibrated log loss: 0.28. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.3. Calibrated log loss: 0.49. Uncalibrated log loss: 0.48.
# Model: bert. Prior: 0.3. Calibrated log loss: 0.26. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.6. Calibrated log loss: 0.55. Uncalibrated log loss: 0.48.
# Model: bert. Prior: 0.8. Calibrated log loss: 0.38. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.5. Calibrated log loss: 0.50. Uncalibrated log loss: 0.48.
# Model: cbow. Prior: 0.4. Calibrated log loss: 0.48. Uncalibrated log loss: 0.48.
# Model: bert. Prior: 0.9. Calibrated log loss: 0.51. Uncalibrated log loss: 0.26.
# Model: bert. Prior: 0.4. Calibrated log loss: 0.25. Uncalibrated log loss: 0.26.
# Model: bert. Prior: 0.7. Calibrated log loss: 0.32. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.7. Calibrated log loss: 0.63. Uncalibrated log loss: 0.48.
# Model: cbow. Prior: 0.1. Calibrated log loss: 0.67. Uncalibrated log loss: 0.48.
# Model: bert. Prior: 0.1. Calibrated log loss: 0.37. Uncalibrated log loss: 0.26.
# Model: bert. Prior: 0.2. Calibrated log loss: 0.28. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.9. Calibrated log loss: 1.06. Uncalibrated log loss: 0.48.
# Model: bert. Prior: 0.5. Calibrated log loss: 0.26. Uncalibrated log loss: 0.26.
# Model: cbow. Prior: 0.8. Calibrated log loss: 0.77. Uncalibrated log loss: 0.48.
# Model: cbow. Prior: 0.2. Calibrated log loss: 0.53. Uncalibrated log loss: 0.48.

# %%
outputs_validation = np.empty(shape=0)
outputs_calibration= np.empty(shape=0)
labels= np.empty(shape=0,dtype=np.int32)
fig, ax = plt.subplots(2, 2, figsize = (12,12))
ax_start=0
for model in ["cbow","bert"]:
   
   with open(path.abspath("../../00_train_system/"+model+"_results.pkl"), 'rb') as f:
      modelOutputs = pkl.load(f)
   calibrationOutputs = np.load(path.abspath(f"../../01_calibrate_system/results/{model}/run00_0/00_Calibration/results.npz"))

   outputs_validation = np.append(outputs_validation,modelOutputs["validation"]["logits"])
   outputs_calibration = np.append(outputs_calibration,calibrationOutputs["logits"])
   labels = np.append(labels,modelOutputs["validation"]["labels"])    

   


   class_1_labels = np.where(labels == 0)[0]
   class_2_labels = np.where(labels == 1)[0]
   ax[ax_start][0].set_title(f"log posteriors de validación en modelo "+model)

   ax[ax_start][0].hist([outputs_validation[class_2_labels], outputs_validation[class_1_labels]], 40, label=['label = 1', 'label = 0'],density=True)
   ax[ax_start][0].legend(loc='upper right')

   ax[ax_start][1].set_title(f"log posteriors de calibración en modelo "+model)

   ax[ax_start][1].hist([outputs_calibration[class_2_labels], outputs_calibration[class_1_labels]], 40, label=['label = 1', 'label = 0'],density=True);

   ax_start +=1
